# %% [markdown]
# # Chapter: Theory
# ## Section: Milky Way ALPs

# %%
import os
import sys
# print(os.path.abspath(os.curdir))
os.chdir("..")  # go to parent folder
print(os.path.abspath(os.curdir))
sys.path.insert(0, os.path.abspath(os.curdir))
from src.dependency import *
from src.constants import *
# Out:
# c:\Users\zhenf\D\Yu0702\CASPEr-Collaboration\ZhangYuzhe-Dissertation

# %% [markdown]
# #### ALP field gradient

# %% [markdown]
# ##### Pseudomagnetic field

# %%
# MW axion
g_aNN = 1e-9 * unit.GeV**-1
rhoE_DM = 0.4 * unit.GeV / unit.cm**3
v_perp = 220 * unit.km / unit.s
Omega_a = 0.5 * g_aNN * np.sqrt(2 * const.hbar * const.c * rhoE_DM) * v_perp * unit.rad
Omega_a = Omega_a.to(unit.rad * unit.Hz)
period_a = (2 * PI / Omega_a).to(unit.year)
B_a_proton = (Omega_a / gamma_p).to(unit.tesla)
B_a_Xe129 = (Omega_a / gamma_Xe129).to(unit.tesla)
print(f"at g_aNN = {g_aNN:.1e}")
print(f"ALP gradient Rabi frequency / 2π = {Omega_a/(2*PI):.1e}")
print(f"ALP gradient pseudomagnetic field (for proton nuclear spin) = {B_a_proton:.1e}")
print(f"ALP gradient pseudomagnetic field (for Xe-129 nuclear spin) = {B_a_Xe129:.1e}")
print(f"Xe-129 gyromagnetic ratio = 2 pi {(gamma_Xe129/(2*PI)).to(unit.MHz / unit.T)}")
print(f"ALP gradient pseudomagnetic field period = {period_a:.1e}")
# Out:
# at g_aNN = 1.0e-09 1 / GeV
# ALP gradient Rabi frequency / 2π = 2.2e-10 Hz
# ALP gradient pseudomagnetic field (for proton nuclear spin) = 5.2e-18 T
# ALP gradient pseudomagnetic field (for Xe-129 nuclear spin) = -1.9e-17 T
# Xe-129 gyromagnetic ratio = 2 pi -11.86015633103308 MHz / T
# ALP gradient pseudomagnetic field period = 1.4e+02 yr
